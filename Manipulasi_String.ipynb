# %% [markdown]
# **String**

# %%
nama = 'Youngky'
asal = " Indonesia"

# %%
print (nama)
# Out:
# Youngky

# %%
print (asal)
# Out:
# Indonesia

# %% [markdown]
# **Manipulasi String**

# %%
print (nama,asal)
# Out:
# Youngky Indonesia

# %%
print (nama+asal)
# Out:
# Youngky Indonesia

# %%
print ("halo, nama saya", nama)
# Out:
# halo, nama saya Youngky

# %%
print ("halo, nama saya", nama, "asal saya dari", asal)
# Out:
# halo, nama saya Youngky asal saya dari  Indonesia

# %%
data_lengkap_banget_fix_final = nama + asal
DataLengkapBanget = nama + asal
datalengkap = nama + asal
data_lengkap = nama + asal

# %%
print (data_lengkap)
# Out:
# Youngky Indonesia

# %% [markdown]
# **String + Non String**

# %%
asal_kota = "Bandar Lampung "
kode_pos = 35111

asal_kota_kode_pos = asal_kota + str(kode_pos)

print (asal_kota_kode_pos)
# Out:
# Bandar Lampung 35111

# %%
asal_kota_x3 = asal_kota * 3

print (asal_kota_x3)
# Out:
# Bandar Lampung Bandar Lampung Bandar Lampung
